# %% [markdown]
# ## Advanced Lane Finding Project
#
# The goals / steps of this project are the following:
#
# * Compute the camera calibration matrix and distortion coefficients given a set of chessboard images.
# * Apply a distortion correction to raw images.
# * Use color transforms, gradients, etc., to create a thresholded binary image.
# * Apply a perspective transform to rectify binary image ("birds-eye view").
# * Detect lane pixels and fit to find the lane boundary.
# * Determine the curvature of the lane and vehicle position with respect to center.
# * Warp the detected lane boundaries back onto the original image.
# * Output visual display of the lane boundaries and numerical estimation of lane curvature and vehicle position.
#
# ---
# ## First, I'll compute the camera calibration using chessboard images

# %%
# !sudo apt-get install libopencv-* -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libopencv-core-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-gpu-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-legacy2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-apps0d' for glob 'libopencv-*'
# Note, selecting 'libopencv-video2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-calib3d-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-ml-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-imgproc2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-objdetect2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-video2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-highgui2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-apps-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-calib3d2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-ocl-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-ml2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-imgproc2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-ts2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-ocl2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-objdetect2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-flann2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-contrib2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-stitching-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-highgui2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-features2d-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-superres-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-photo2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-gpu2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-features2d2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-stitching2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-stitching2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-flann-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-flann2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-superres2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-calib3d2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-imgproc-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-contrib-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-ts2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-legacy2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-gpu2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-videostab2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-legacy-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-core2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-contrib2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-superres2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-photo-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-ml2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-objdetect-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-core2.4' for glob 'libopencv-*'
# Note, selecting 'libopencv-videostab-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-doc' for glob 'libopencv-*'
# Note, selecting 'libopencv-features2d2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-ts-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-video-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-highgui-dev' for glob 'libopencv-*'
# Note, selecting 'libopencv-videostab2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-ocl2.4v5' for glob 'libopencv-*'
# Note, selecting 'libopencv-photo2.4' for glob 'libopencv-*'
# libopencv-core2.4v5 is already the newest version (2.4.9.1+dfsg-1.5ubuntu1.1).
# libopencv-core2.4v5 set to manually installed.
# libopencv-imgproc2.4v5 is already the newest version (2.4.9.1+dfsg-1.5ubuntu1.1).
# libopencv-imgproc2.4v5 set to manually installed.
# The following additional packages will be installed:
#   libbond-dev libbondcpp-dev libbondcpp0d libclass-loader-dev
#   libclass-loader0d libconsole-bridge-dev libconsole-bridge0.2v5
#   libcpp-common0d libcv-bridge-dev libcv-bridge0d libcv-dev libcvaux-dev
#   libdc1394-22-dev libdynamic-reconfigure-config-init-mutex-dev
#   libdynamic-reconfigure-config-init-mutex0d libgeometry-msgs-dev libgtkglext1
#   libhighgui-dev libilmbase-dev libilmbase12 libimage-transport-dev
#   libimage-transport0d libjasper-dev libjasper1 libjbig-dev liblzma-dev
#   libmessage-filters-dev libmessage-filters0d libmysqlclient20 libnodelet-dev
#   libnodeletlib-dev libnodeletlib0d libodbc1 libopencv2.4-java
#   libopencv2.4-jni libopenexr-dev libopenexr22 libpangox-1.0-0 libpoco-dev
#   libpococrypto9v5 libpocodata9v5 libpocofoundation9v5 libpocomysql9v5
#   libpoconet9v5 libpoconetssl9v5 libpocoodbc9v5 libpocosqlite9v5
#   libpocoutil9v5 libpocoxml9v5 libpocozip9v5 libraw1394-dev libraw1394-tools
#   libros-rosgraph-msgs-dev librosconsole-dev librosconsole0d
#   libroscpp-core-dev libroscpp-dev libroscpp-msgs-dev
#   libroscpp-serialization0d libroscpp0d libroslib-dev libroslib0d
#   librospack-dev librospack0d librostime0d libsensor-msgs-dev libsmc-dev
#   libstd-msgs-dev libtiff5-dev libtiffxx5 libtinyxml-dev libtinyxml2.6.2v5
#   libv4l-0 libv4lconvert0 libxmlrpcpp-dev libxmlrpcpp0d mysql-common
#   opencv-data pluginlib-dev python-gencpp python-genlisp python-genmsg
#   python-genpy ros-cmake-modules ros-message-generation ros-message-runtime
#   uuid-dev
# Suggested packages:
#   libjasper-runtime liblzma-doc libmyodbc odbc-postgresql tdsodbc unixodbc-bin
#   libpoco-doc libpococrypto9v5-dbg libpocodata9v5-dbg libpocofoundation9v5-dbg
#   libpocomysql9v5-dbg libpoconet9v5-dbg libpoconetssl9v5-dbg
#   libpocoodbc9v5-dbg libpocosqlite9v5-dbg libpocoutil9v5-dbg libpocoxml9v5-dbg
#   libpocozip9v5-dbg libraw1394-doc libtinyxml-doc
# The following NEW packages will be installed:
#   libbond-dev libbondcpp-dev libbondcpp0d libclass-loader-dev
#   libclass-loader0d libconsole-bridge-dev libconsole-bridge0.2v5
#   libcpp-common0d libcv-bridge-dev libcv-bridge0d libcv-dev libcvaux-dev
#   libdc1394-22-dev libdynamic-reconfigure-config-init-mutex-dev
#   libdynamic-reconfigure-config-init-mutex0d libgeometry-msgs-dev libgtkglext1
#   libhighgui-dev libilmbase-dev libilmbase12 libimage-transport-dev
#   libimage-transport0d libjasper-dev libjasper1 libjbig-dev liblzma-dev
#   libmessage-filters-dev libmessage-filters0d libmysqlclient20 libnodelet-dev
#   libnodeletlib-dev libnodeletlib0d libodbc1 libopencv-apps-dev
#   libopencv-apps0d libopencv-calib3d-dev libopencv-calib3d2.4v5
#   libopencv-contrib-dev libopencv-contrib2.4v5 libopencv-core-dev
#   libopencv-dev libopencv-features2d-dev libopencv-features2d2.4v5
#   libopencv-flann-dev libopencv-flann2.4v5 libopencv-gpu-dev
#   libopencv-gpu2.4v5 libopencv-highgui-dev libopencv-highgui2.4v5
#   libopencv-imgproc-dev libopencv-legacy-dev libopencv-legacy2.4v5
#   libopencv-ml-dev libopencv-ml2.4v5 libopencv-objdetect-dev
#   libopencv-objdetect2.4v5 libopencv-ocl-dev libopencv-ocl2.4v5
#   libopencv-photo-dev libopencv-photo2.4v5 libopencv-stitching-dev
#   libopencv-stitching2.4v5 libopencv-superres-dev libopencv-superres2.4v5
#   libopencv-ts-dev libopencv-ts2.4v5 libopencv-video-dev libopencv-video2.4v5
#   libopencv-videostab-dev libopencv-videostab2.4v5 libopencv2.4-java
#   libopencv2.4-jni libopenexr-dev libopenexr22 libpangox-1.0-0 libpoco-dev
#   libpococrypto9v5 libpocodata9v5 libpocofoundation9v5 libpocomysql9v5
#   libpoconet9v5 libpoconetssl9v5 libpocoodbc9v5 libpocosqlite9v5
#   libpocoutil9v5 libpocoxml9v5 libpocozip9v5 libraw1394-dev libraw1394-tools
#   libros-rosgraph-msgs-dev librosconsole-dev librosconsole0d
#   libroscpp-core-dev libroscpp-dev libroscpp-msgs-dev
#   libroscpp-serialization0d libroscpp0d libroslib-dev libroslib0d
#   librospack-dev librospack0d librostime0d libsensor-msgs-dev libsmc-dev
#   libstd-msgs-dev libtiff5-dev libtiffxx5 libtinyxml-dev libtinyxml2.6.2v5
#   libv4l-0 libv4lconvert0 libxmlrpcpp-dev libxmlrpcpp0d mysql-common
#   opencv-data pluginlib-dev python-gencpp python-genlisp python-genmsg
#   python-genpy ros-cmake-modules ros-message-generation ros-message-runtime
#   uuid-dev
# 0 upgraded, 124 newly installed, 0 to remove and 0 not upgraded.
# Need to get 2,911 kB/18.1 MB of archives.
# After this operation, 105 MB of additional disk space will be used.
# Err:1 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libopenexr22 amd64 2.2.0-10ubuntu2.3
#   404  Not Found [IP: 91.189.88.142 80]
# Err:1 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libopenexr22 amd64 2.2.0-10ubuntu2.3
#   404  Not Found [IP: 91.189.88.142 80]
# Err:2 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libopenexr-dev amd64 2.2.0-10ubuntu2.3
#   404  Not Found [IP: 91.189.88.142 80]
# Ign:3 http://security.ubuntu.com/ubuntu xenial-security/main amd64 mysql-common all 5.7.31-0ubuntu0.16.04.1
# Ign:4 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libmysqlclient20 amd64 5.7.31-0ubuntu0.16.04.1
# Ign:5 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libjasper1 amd64 1.900.1-debian1-2.4ubuntu1.2
# Ign:6 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libjasper-dev amd64 1.900.1-debian1-2.4ubuntu1.2
# Ign:7 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libtiffxx5 amd64 4.0.6-1ubuntu0.7
# Ign:8 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libtiff5-dev amd64 4.0.6-1ubuntu0.7
# Err:2 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libopenexr-dev amd64 2.2.0-10ubuntu2.3
#   404  Not Found [IP: 91.189.88.142 80]
# Err:3 http://security.ubuntu.com/ubuntu xenial-security/main amd64 mysql-common all 5.7.31-0ubuntu0.16.04.1
#   404  Not Found [IP: 91.189.88.142 80]
# Err:4 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libmysqlclient20 amd64 5.7.31-0ubuntu0.16.04.1
#   404  Not Found [IP: 91.189.88.142 80]
# Err:5 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libjasper1 amd64 1.900.1-debian1-2.4ubuntu1.2
#   404  Not Found [IP: 91.189.88.142 80]
# Err:6 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libjasper-dev amd64 1.900.1-debian1-2.4ubuntu1.2
#   404  Not Found [IP: 91.189.88.142 80]
# Err:7 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libtiffxx5 amd64 4.0.6-1ubuntu0.7
#   404  Not Found [IP: 91.189.88.142 80]
# Err:8 http://security.ubuntu.com/ubuntu xenial-security/main amd64 libtiff5-dev amd64 4.0.6-1ubuntu0.7
#   404  Not Found [IP: 91.189.88.142 80]
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/o/openexr/libopenexr22_2.2.0-10ubuntu2.3_amd64.deb  404  Not Found [IP: 91.189.88.142 80]
#
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/o/openexr/libopenexr-dev_2.2.0-10ubuntu2.3_amd64.deb  404  Not Found [IP: 91.189.88.142 80]
#
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/m/mysql-5.7/mysql-common_5.7.31-0ubuntu0.16.04.1_all.deb  404  Not Found [IP: 91.189.88.142 80]
#
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/m/mysql-5.7/libmysqlclient20_5.7.31-0ubuntu0.16.04.1_amd64.deb  404  Not Found [IP: 91.189.88.142 80]
#
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/j/jasper/libjasper1_1.900.1-debian1-2.4ubuntu1.2_amd64.deb  404  Not Found [IP: 91.189.88.142 80]
#
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/j/jasper/libjasper-dev_1.900.1-debian1-2.4ubuntu1.2_amd64.deb  404  Not Found [IP: 91.189.88.142 80]
#
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/t/tiff/libtiffxx5_4.0.6-1ubuntu0.7_amd64.deb  404  Not Found [IP: 91.189.88.142 80]
#
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/t/tiff/libtiff5-dev_4.0.6-1ubuntu0.7_amd64.deb  404  Not Found [IP: 91.189.88.142 80]
#
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?

# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
# %matplotlib qt

# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((6*9,3), np.float32)
objp[:,:2] = np.mgrid[0:9,0:6].T.reshape(-1,2)

# Arrays to store object points and image points from all the images.
objpoints = [] # 3d points in real world space
imgpoints = [] # 2d points in image plane.

# Make a list of calibration images
images = glob.glob('../camera_cal/calibration*.jpg')

# Step through the list and search for chessboard corners
for fname in images:
    img = cv2.imread(fname)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

    # Find the chessboard corners
    ret, corners = cv2.findChessboardCorners(gray, (9,6),None)

    # If found, add object points, image points
    if ret == True:
        objpoints.append(objp)
        imgpoints.append(corners)

        # Draw and display the corners
        img = cv2.drawChessboardCorners(img, (9,6), corners, ret)
        plt.imshow('img',img)
        cv2.waitKey(500)

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ce145e672789> in <module>()
#      31         # Draw and display the corners
#      32         img = cv2.drawChessboardCorners(img, (9,6), corners, ret)
# ---> 33         plt.imshow('img',img)
#      34         cv2.waitKey(500)
#      35
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3078                         filternorm=filternorm, filterrad=filterrad,
#    3079                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3080                         **kwargs)
#    3081     finally:
#    3082         ax._hold = washold
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5190         im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    5191                               filternorm=filternorm, filterrad=filterrad,
# -> 5192                               resample=resample, **kwargs)
#    5193
#    5194         im.set_data(X)
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/image.py in __init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, **kwargs)
#     755             filterrad=filterrad,
#     756             resample=resample,
# --> 757             **kwargs
#     758         )
#     759
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/image.py in __init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, **kwargs)
#     220         """
#     221         martist.Artist.__init__(self)
# --> 222         cm.ScalarMappable.__init__(self, norm, cmap)
#     223         self._mouseover = True
#     224         if origin is None:
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/cm.py in __init__(self, norm, cmap)
#     202         self.norm = norm
#     203         #: The Colormap instance of this ScalarMappable.
# --> 204         self.cmap = get_cmap(cmap)
#     205         #: The last colorbar associated with this ScalarMappable. May be None.
#     206         self.colorbar = None
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/cm.py in get_cmap(name, lut)
#     159         return name
#     160
# --> 161     if name in cmap_d:
#     162         if lut is None:
#     163             return cmap_d[name]
#
# TypeError: unhashable type: 'numpy.ndarray'

# %% [markdown]
# ## And so on and so forth...
